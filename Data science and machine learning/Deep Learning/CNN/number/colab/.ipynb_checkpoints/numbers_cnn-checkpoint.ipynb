# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile
zip_file = 'drive/MyDrive/AI/CNN/numbers/Numbers_Images_Dataset.zip'
with zipfile.ZipFile(zip_file,'r') as zip_ref:
    zip_ref.extractall('images')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf

# %%
directory_path = "/content/images"
images_df = pd.read_csv(directory_path + "/numbers.csv")
images_df
# Out:
#          origin    group  label                                           file
# 0      chars74k  GoodImg      8  chars74k_png/GoodImg/Sample8/img009-00029.png
# 1      chars74k  GoodImg      8  chars74k_png/GoodImg/Sample8/img009-00032.png
# 2      chars74k  GoodImg      8  chars74k_png/GoodImg/Sample8/img009-00020.png
# 3      chars74k  GoodImg      8  chars74k_png/GoodImg/Sample8/img009-00027.png
# 4      chars74k  GoodImg      8  chars74k_png/GoodImg/Sample8/img009-00022.png
# ...         ...      ...    ...                                            ...
# 71585     mnist      Hnd      0                mnist_png/Hnd/Sample0/45577.png
# 71586     mnist      Hnd      0                mnist_png/Hnd/Sample0/19491.png
# 71587     mnist      Hnd      0                mnist_png/Hnd/Sample0/30425.png
# 71588     mnist      Hnd      0                mnist_png/Hnd/Sample0/11240.png
# 71589     mnist      Hnd      0                mnist_png/Hnd/Sample0/49278.png
#
# [71590 rows x 4 columns]

# %%
from pathlib import Path

def create_directory(directory_path):
    # Create a directory if it doesn't exist
    try:
        Path(directory_path).mkdir(parents=True, exist_ok=True)
        print(f"Directory '{directory_path}' created successfully.")
    except OSError as e:
        print(f"Error creating directory: {e}")

import shutil

def copy_file(source_path, destination_path):
    try:
        shutil.copy(source_path, destination_path)
        print(f"File copied from '{source_path}' to '{destination_path}' successfully.")
    except Exception as e:
        print(f"Error copying file: {e}")

# %%
create_directory(directory_path + "/" + "test")
create_directory(directory_path + "/" + "train")
folders = []
for i in range(0,10):
    folders.append(f"Sample{i}")
    create_directory(f'{directory_path}/train/Sample{i}')
    create_directory(f'{directory_path}/test/Sample{i}')
# Out:
# Directory '/content/images/test' created successfully.
# Directory '/content/images/train' created successfully.
# Directory '/content/images/train/Sample0' created successfully.
# Directory '/content/images/test/Sample0' created successfully.
# Directory '/content/images/train/Sample1' created successfully.
# Directory '/content/images/test/Sample1' created successfully.
# Directory '/content/images/train/Sample2' created successfully.
# Directory '/content/images/test/Sample2' created successfully.
# Directory '/content/images/train/Sample3' created successfully.
# Directory '/content/images/test/Sample3' created successfully.
# Directory '/content/images/train/Sample4' created successfully.
# Directory '/content/images/test/Sample4' created successfully.
# Directory '/content/images/train/Sample5' created successfully.
# Directory '/content/images/test/Sample5' created successfully.
# Directory '/content/images/train/Sample6' created successfully.
# Directory '/content/images/test/Sample6' created successfully.
# Directory '/content/images/train/Sample7' created successfully.
# Directory '/content/images/test/Sample7' created successfully.
# Directory '/content/images/train/Sample8' created successfully.
# Directory '/content/images/test/Sample8' created successfully.
# Directory '/content/images/train/Sample9' created successfully.
# Directory '/content/images/test/Sample9' created successfully.

png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/24998.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54449.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37306.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/34844.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/14182.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/42017.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/40583.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/58818.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10722.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52546.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37586.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38727.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/374.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31532.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/1960.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/58961.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/28761.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16470.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18813.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/27164.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/21827.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18111.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/50851.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53951.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/57449.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/14151.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23423.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/14235.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/28168.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38265.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/59858.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/13265.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/29737.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54738.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18510.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31325.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/43734.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9127.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/12475.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38353.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/34892.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/40250.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33358.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/41178.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36679.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/15837.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10112.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/13057.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/50787.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/12417.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/32767.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/24054.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33746.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53265.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/44084.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/601.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10043.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/43193.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/55835.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/2371.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/35479.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/25969.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/21378.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/25667.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53597.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/57333.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36249.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/3227.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/1855.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53948.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18193.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/12999.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9893.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36000.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/41603.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/27848.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/5577.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9407.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/8514.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/32121.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52315.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23719.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/46168.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/7676.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37474.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/50747.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37593.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/24983.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/24911.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/46609.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38519.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23327.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10165.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33531.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/7873.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/49669.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56839.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/707.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/42192.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23016.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/1962.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/14681.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/51581.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/6376.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/35894.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31326.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56237.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/11900.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37136.png' to '/content/images/train/Sample9' successfully.
# ...
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53146.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9889.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23542.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/50088.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/4901.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/48344.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/44048.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/48244.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31480.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52328.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/11668.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36161.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/37877.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18211.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/49793.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16973.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/6295.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/41008.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/1421.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10184.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/4306.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/11224.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/24556.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/5701.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/49764.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/39139.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/50003.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18561.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/23512.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31088.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9132.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10516.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36735.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/5607.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/15693.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54667.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/7690.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56413.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/42802.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/5062.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/35194.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/22223.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/3925.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31822.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/5063.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/30342.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/29905.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18728.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/28424.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31262.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/58006.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/2562.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54850.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/7310.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/12495.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/32555.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/4816.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/4678.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/15089.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/11175.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54323.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33226.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/49495.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/583.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/29084.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/59771.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/9225.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52467.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10794.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/45739.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/6092.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56618.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/6769.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/44177.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/57294.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/17860.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/29492.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52618.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/40584.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/58263.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/31697.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/32891.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/55859.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/10799.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/29305.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16201.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/55063.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/22927.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/41097.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/19412.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/54138.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/41583.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/45227.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38992.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/22692.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/7627.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/20683.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/21020.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18448.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/39195.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/43750.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/38082.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/20818.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52651.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/25648.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/30698.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33291.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/20879.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56478.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/52943.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/36402.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/58921.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/18828.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/51757.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/55938.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53868.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/56201.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16981.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/59973.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/14796.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16877.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/12171.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/26558.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/20820.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/53703.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/39480.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/35239.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/16103.png' to '/content/images/train/Sample9' successfully.
# File copied from '/content/images/numbers/mnist_png/Hnd/Sample9/33981.png' to '/content/images/train/Sample9' successfully.

# %%
tf.config.set_visible_devices([],'GPU')
print('Available GPU cores ', len(tf.config.experimental.list_physical_devices('GPU')))
# Out:
# Available GPU cores  1

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
train_data_genarator = ImageDataGenerator(
    rescale=1./255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    )

test_data_generator = ImageDataGenerator(
    rescale=1./255
    )

# %%
train_data = train_data_genarator.flow_from_directory(
    directory_path + "/" + 'train',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)

test_data = test_data_generator.flow_from_directory(
    directory_path + "/" + 'test',
    target_size=(64,64),
    batch_size=32,
    class_mode='categorical'
)
# Out:
# Found 64344 images belonging to 10 classes.
# Found 6771 images belonging to 10 classes.

# %%
cnn = tf.keras.models.Sequential()
# First convolutional layer

cnn.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=3,
    activation='relu',
    input_shape=[64,64,3]
    )
)

cnn.add(tf.keras.layers.MaxPool2D(
    pool_size=(2,2),
    strides=(2,2),
    padding='valid'
    )
)

# hidden convolutional layer

cnn.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=3,
    activation='relu'
    )
)

cnn.add(tf.keras.layers.MaxPool2D(
    pool_size=(2,2),
    strides=(2,2),
    padding='valid'
    )
)


cnn.add(tf.keras.layers.Conv2D(
    filters=32,
    kernel_size=3,
    activation='relu'
    )
)

cnn.add(tf.keras.layers.MaxPool2D(
    pool_size=(2,2),
    strides=(2,2),
    padding='valid'
    )
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
cnn.add(tf.keras.layers.Flatten())

# %%
cnn.add(tf.keras.layers.Dense(128,activation='relu'))
cnn.add(tf.keras.layers.Dense(128,activation='relu'))
# Output layer
cnn.add(tf.keras.layers.Dense(10,activation='relu'))

# %%
cnn.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
cnn.fit(train_data,validation_data=test_data,epochs=30,batch_size=32)
# Out:
# Epoch 1/30
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 631s 312ms/step - accuracy: 0.4775 - loss: 2.6904 - val_accuracy: 0.0922 - val_loss: 2.6918
# Epoch 2/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 611s 304ms/step - accuracy: 0.6185 - loss: 1.3816 - val_accuracy: 0.0956 - val_loss: 2.2812
# Epoch 3/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 609s 302ms/step - accuracy: 0.6626 - loss: 1.1954 - val_accuracy: 0.1041 - val_loss: 2.3335
# Epoch 4/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 628s 305ms/step - accuracy: 0.7075 - loss: 1.0363 - val_accuracy: 0.3067 - val_loss: 2.0881
# Epoch 5/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 629s 312ms/step - accuracy: 0.8216 - loss: 0.7758 - val_accuracy: 0.3101 - val_loss: 2.0215
# Epoch 6/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 705s 324ms/step - accuracy: 0.8032 - loss: 0.7878 - val_accuracy: 0.6962 - val_loss: 1.2963
# Epoch 7/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 657s 311ms/step - accuracy: 0.8788 - loss: 0.5777 - val_accuracy: 0.7225 - val_loss: 1.2655
# Epoch 8/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 670s 305ms/step - accuracy: 0.8990 - loss: 0.4852 - val_accuracy: 0.4036 - val_loss: 1.4389
# Epoch 9/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 611s 304ms/step - accuracy: 0.9117 - loss: 0.4623 - val_accuracy: 0.5420 - val_loss: 1.4586
# Epoch 10/30
# 2011/2011 ━━━━━━━━━━━━━━━━━━━━ 624s 304ms/step - accuracy: 0.8842 - loss: 0.6034 - val_accuracy: 0.7946 - val_loss: 0.9177
# Epoch 11/30
# 1532/2011 ━━━━━━━━━━━━━━━━━━━━ 2:21 295ms/step - accuracy: 0.9193 - loss: 0.4380

# %%
from joblib import dump
dump(cnn, directory_path + "/model/" + 'numbers.joblib')

# %%
from joblib import load
cnn = load(directory_path + "/model/" + 'numbers.joblib')
from tensorflow.keras.preprocessing import image
directory_path = "drive/MyDrive/AI/CNN/numbers/images/new_data"
images = list_files_in_directory(directory_path)

results = []
for image in images:
    test_img = image.load_img(directory_path + "/new_data/" + images[i])]
    test_image = image.img_to_array(test_img)
    test_image = test_image/255
    test_image = np.expand_dims(test_image,axis=0)
    result = cnn.predict(test_image)
    results.append(result)
print(results)
