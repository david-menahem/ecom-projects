# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x = np.arange(10)
y_linear = x*2

# %%
plt.plot(x,y_linear)
plt.show()

# %%
y_scatter = np.random.rand(10)
plt.scatter(x,y_scatter)
plt.show()

# %%
bar_categories = ['A','B','C','D','E']
bar_values = np.random.rand(5)
colors = ['blue','#0000ff','red','green','orange']

# %%
plt.bar(bar_categories,bar_values,color=colors)
# Out:
# <BarContainer object of 5 artists>

# %%
y_hist = np.random.rand(1000)
plt.hist(y_hist,bins=20)
# Out:
# (array([52., 58., 48., 52., 54., 40., 54., 55., 50., 44., 33., 57., 46.,
#         60., 47., 52., 50., 50., 43., 55.]),
#  array([9.40975132e-05, 5.00698993e-02, 1.00045701e-01, 1.50021503e-01,
#         1.99997305e-01, 2.49973106e-01, 2.99948908e-01, 3.49924710e-01,
#         3.99900512e-01, 4.49876314e-01, 4.99852115e-01, 5.49827917e-01,
#         5.99803719e-01, 6.49779521e-01, 6.99755322e-01, 7.49731124e-01,
#         7.99706926e-01, 8.49682728e-01, 8.99658530e-01, 9.49634331e-01,
#         9.99610133e-01]),
#  <BarContainer object of 20 artists>)
