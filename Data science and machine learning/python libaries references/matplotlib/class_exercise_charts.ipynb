# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv/matplotlib_subplot_class_exc.csv')
df.drop('Unnamed: 0', axis=1, inplace=True)
df
# Out:
#      Year  Country  GDP per Capita
# 0    1995      USA           22732
# 1    1995   Canada           41243
# 2    1995       UK           50403
# 3    1995  Germany           52103
# 4    1995   France           40757
# ..    ...      ...             ...
# 110  2017      USA           34368
# 111  2017   Canada           25302
# 112  2017       UK           53920
# 113  2017  Germany           43334
# 114  2017   France           58062
#
# [115 rows x 3 columns]

# %%
usa = df[df['Country'] =='USA']
print(usa)
plt.plot(usa['Year'],usa['GDP per Capita'])
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
# Out:
#      Year Country  GDP per Capita
# 0    1995     USA           22732
# 5    1996     USA           34935
# 10   1997     USA           52230
# 15   1998     USA           47469
# 20   1999     USA           25072
# 25   2000     USA           27599
# 30   2001     USA           20797
# 35   2002     USA           39129
# 40   2003     USA           46752
# 45   2004     USA           45332
# 50   2005     USA           46681
# 55   2006     USA           39340
# 60   2007     USA           59876
# 65   2008     USA           29396
# 70   2009     USA           55725
# 75   2010     USA           25795
# 80   2011     USA           36221
# 85   2012     USA           30215
# 90   2013     USA           32843
# 95   2014     USA           29123
# 100  2015     USA           58299
# 105  2016     USA           56950
# 110  2017     USA           34368

# %%
year_2015 = df[df['Year'] == 2015]

# %%
plt.hist(year_2015['GDP per Capita'])
plt.xlabel('Gdp range')
plt.title('2015')
plt.ylabel('GDP')
plt.show()

# %%
year_2010 = df[df['Year'] == 2010]
year_2010
plt.bar(year_2010['Country'],year_2010['GDP per Capita'])
plt.title('2010')
plt.ylim(50000,70000)
plt.xlabel('Country')
plt.ylabel('GDP')
plt.show()

# %%
plt.scatter(usa['Year'],usa['GDP per Capita'])
plt.title('Year/GDP')
plt.xlabel('Year')
plt.ylabel('GDP')
plt.show()
