# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
blobs = pd.read_csv('cluster_blobs.csv')
blobs
# Out:
#             X1        X2
# 0     4.645333  6.822294
# 1     4.784032  6.422883
# 2    -5.851786  5.774331
# 3    -7.459592  6.456415
# 4     4.918911  6.961479
# ...        ...       ...
# 1495  0.882673 -6.786272
# 1496  0.946854 -7.254512
# 1497  3.180138  6.608660
# 1498  5.454552  6.461246
# 1499 -7.769230  7.014384
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=blobs,x='X1',y='X2')
plt.show()

# %%
moons = pd.read_csv('cluster_moons.csv')
circles = pd.read_csv('cluster_circles.csv')
circles
# Out:
#             X1        X2
# 0    -0.348677  0.010157
# 1    -0.176587 -0.954283
# 2     0.301703 -0.113045
# 3    -0.782889 -0.719468
# 4    -0.733280 -0.757354
# ...        ...       ...
# 1495 -0.297506  0.077834
# 1496  0.082555 -0.270371
# 1497  0.279533 -0.109435
# 1498  0.027432 -0.264891
# 1499 -0.216732  0.183006
#
# [1500 rows x 2 columns]

# %%
sns.scatterplot(data=moons,x='X1',y='X2')
plt.show()

# %%
sns.scatterplot(data=circles,x='X1',y='X2')
plt.show()

# %%
def display_scatterplot(model,data):
    labels = model.fit_predict(data)
    sns.scatterplot(data=data,x='X1',y='X2',hue=labels,palette='Set1')
    plt.show()

# %%
from sklearn.cluster import KMeans
model = KMeans(n_clusters=3)

# %%
display_scatterplot(model,blobs)

# %%
model = KMeans(n_clusters=2)
display_scatterplot(model,moons)

# %%
display_scatterplot(model,circles)

# %%
from sklearn.cluster import KMeans,DBSCAN
model = DBSCAN(eps=2)
display_scatterplot(model,blobs)
model = DBSCAN(eps=0.15)
display_scatterplot(model,moons)
display_scatterplot(model,circles)

# %%
two_blobs_outliers = pd.read_csv('cluster_two_blobs_outliers.csv')
sns.scatterplot(data=two_blobs_outliers,x='X1',y='X2')
plt.show()

# %%
model = DBSCAN()
display_scatterplot(model,two_blobs_outliers)

# %%
model = DBSCAN(eps=0.001)
display_scatterplot(model,two_blobs_outliers)

# %%
model = DBSCAN(eps=10)
display_scatterplot(model,two_blobs_outliers)

# %%
model = DBSCAN(min_samples=1)
display_scatterplot(model,two_blobs_outliers)

# %%
model = DBSCAN(min_samples=10)
display_scatterplot(model,two_blobs_outliers)

# %%
model = DBSCAN(eps=1)
display_scatterplot(model,two_blobs_outliers)

# %%
eps = np.linspace(0.001,10,1000)
percentages = []
outliers = []
for e in eps: 
    model = DBSCAN(eps=e)
    model.fit(two_blobs_outliers)
    labels = model.labels_
    num_outliers = np.sum(labels==-1)
    outliers.append(num_outliers)
    outliers_percentage = num_outliers*100/len(labels)
    percentages.append(outliers_percentage)

# %%
plt.plot(eps,outliers)
plt.xlim(0,1)
plt.ylim(0,10)
plt.hlines(y=3,xmin=0,xmax=1,colors='red')
plt.show()

# %%
mins = range(1,1000)
percentages = []
outliers = []
for min in mins: 
    model = DBSCAN(min_samples=min)
    model.fit(two_blobs_outliers)
    labels = model.labels_
    num_outliers = np.sum(labels==-1)
    outliers.append(num_outliers)
    outliers_percentage = num_outliers*100/len(labels)
    percentages.append(outliers_percentage)

# %%
plt.plot(mins,outliers)
plt.ylim(0,10)
plt.xlim(0,5)
plt.show()
