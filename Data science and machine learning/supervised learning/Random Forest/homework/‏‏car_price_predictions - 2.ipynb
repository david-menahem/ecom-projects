# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
origianl_df = pd.read_csv('CarPricePrediction.csv')
df = origianl_df.copy()
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                NaN  alfa-romero       gas        std
# 1          3                NaN  alfa-romero       gas        std
# 2          1                NaN  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0      111.0
# 1          130         mpfi  3.47    2.68               9.0      111.0
# 2          152         mpfi  2.68    3.47               9.0      154.0
# 3          109         mpfi  3.19    3.40              10.0      102.0
# 4          136         mpfi  3.19    3.40               8.0      115.0
#
#    peak-rpm city-mpg  highway-mpg    price
# 0    5000.0       21           27  13495.0
# 1    5000.0       21           27  16500.0
# 2    5000.0       19           26  16500.0
# 3    5500.0       24           30  13950.0
# 4    5500.0       18           22  17450.0
#
# [5 rows x 26 columns]

# %%
df.isna().sum()
df = df.dropna()

# %%
df.isna().sum()
# Out:
# symboling            0
# normalized-losses    0
# make                 0
# fuel-type            0
# aspiration           0
# num-of-doors         0
# body-style           0
# drive-wheels         0
# engine-location      0
# wheel-base           0
# length               0
# width                0
# height               0
# curb-weight          0
# engine-type          0
# num-of-cylinders     0
# engine-size          0
# fuel-system          0
# bore                 0
# stroke               0
# compression-ratio    0
# horsepower           0
# peak-rpm             0
# city-mpg             0
# highway-mpg          0
# price                0
# dtype: int64

# %%
df.duplicated().unique()
# Out:
# array([False])

# %%
df = pd.get_dummies(df,columns=['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','engine-type',
                                'num-of-cylinders','fuel-system'])

# %%
# sns.pairplot(data=df,hue='price')
# plt.show()

# %%
X = df.drop('price',axis=1)
y = df['price']
df_unique = df.copy()
for col in df.columns:
    df_unique[col] = pd.Series(df[col].unique())
df_unique.head()
# Out:
#     symboling  normalized-losses  wheel-base  length  width  height  \
# 3        -1.0              188.0       101.2   141.1   64.8    53.2
# 4         3.0              121.0        88.4   155.9   60.3    52.0
# 6         NaN               81.0        93.7   157.3   63.8    50.6
# 8         NaN              148.0        95.9   173.2   66.3    50.2
# 10        NaN              145.0        96.5   150.0   64.0    54.5
#
#     curb-weight  engine-size  bore  stroke  ...  num-of-cylinders_five  \
# 3        3086.0        108.0  3.31    3.03  ...                    NaN
# 4        2395.0        164.0  2.91    3.11  ...                    NaN
# 6        2765.0         90.0  2.97    3.39  ...                    NaN
# 8        1874.0        122.0  3.60    3.90  ...                    NaN
# 10       1876.0         92.0  3.15    3.07  ...                    NaN
#
#     num-of-cylinders_four  num-of-cylinders_six  num-of-cylinders_three  \
# 3                     NaN                   NaN                     NaN
# 4                     NaN                   NaN                     NaN
# 6                     NaN                   NaN                     NaN
# 8                     NaN                   NaN                     NaN
# 10                    NaN                   NaN                     NaN
#
#     fuel-system_1bbl  fuel-system_2bbl fuel-system_idi fuel-system_mfi  \
# 3                NaN               NaN             NaN             NaN
# 4                NaN               NaN             NaN             NaN
# 6                NaN               NaN             NaN             NaN
# 8                NaN               NaN             NaN             NaN
# 10               NaN               NaN             NaN             NaN
#
#    fuel-system_mpfi fuel-system_spdi
# 3               NaN              NaN
# 4               NaN              NaN
# 6               NaN              NaN
# 8               NaN              NaN
# 10              NaN              NaN
#
# [5 rows x 65 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error,mean_squared_error

X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
def metrics(y_test,y_pred):
    MAE = mean_absolute_error(y_test,y_pred)
    MSE = mean_squared_error(y_test,y_pred)
    RSME = np.sqrt(MSE)

    MAE_percentage = MAE*100/y.mean()
    RSME_percentage = RSME*100/y.mean()

    print(f'MAE: {MAE}, percentege: {MAE_percentage}\n RSME: {RSME}, percentage: {RSME_percentage}')

# %% [markdown]
# # Simple Decision Tree Machine Learning:

# %%
from sklearn.tree import DecisionTreeRegressor,plot_tree
tree_model = DecisionTreeRegressor()
tree_model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
plt.figure(figsize=(150,120), dpi=50)
plot_tree(tree_model, feature_names=X.columns.tolist(), filled=True)
plt.show()

# %% [markdown]
# # Based on the number of features (20+) and the depth of the tree (12) there maybe overfitting while the gini imprurity is 0

# %%
tree_model.feature_importances_
# Out:
# array([3.63531398e-03, 4.19119893e-02, 2.55613872e-02, 2.13790535e-04,
#        2.09372863e-01, 3.12160908e-05, 6.74223840e-01, 6.82887339e-03,
#        1.20540318e-03, 6.58766516e-05, 9.45502770e-03, 2.95770192e-03,
#        7.69250024e-04, 3.98549508e-03, 6.41943017e-03, 0.00000000e+00,
#        3.32136995e-03, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 1.11429108e-05,
#        0.00000000e+00, 4.95798889e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 3.36021564e-04, 0.00000000e+00,
#        0.00000000e+00, 5.23796258e-04, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 2.11796383e-03, 0.00000000e+00,
#        0.00000000e+00, 1.87041207e-03, 6.95768147e-07, 2.03237652e-04,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#        5.08937053e-05, 0.00000000e+00, 3.76476120e-04, 0.00000000e+00,
#        1.35823644e-03, 0.00000000e+00, 0.00000000e+00, 2.89401484e-06,
#        8.49954994e-07, 0.00000000e+00, 0.00000000e+00, 1.46550904e-04,
#        0.00000000e+00, 0.00000000e+00, 2.54620126e-03, 0.00000000e+00])

# %%
y_pred = tree_model.predict(X_test)
metrics(y_test,y_pred)
# Out:
# MAE: 1600.4791666666667, percentege: 13.983199221263487
#  RSME: 2250.4364252665896, percentage: 19.66179974390425

# %%
sns.regplot(x=y_test,y=y_pred)
plt.show()

# %% [markdown]
# # Optimal Decision Tree Machine Learning:

# %%
len(X_train.columns)
# Out:
# 64

# %%
from sklearn.model_selection import GridSearchCV
max_depth = [4,5,6,7,8]
min_samples_split = [4,6,10,14,18,22]
max_leaf_nodes = [20,35,50]
params = {'max_depth':max_depth,'min_samples_split':min_samples_split,'max_leaf_nodes':max_leaf_nodes}
tree_model = DecisionTreeRegressor()
grid_model = GridSearchCV(tree_model,params,scoring='neg_mean_squared_error')
grid_model.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=DecisionTreeRegressor(),
#              param_grid={'max_depth': [4, 5, 6, 7, 8],
#                          'max_leaf_nodes': [20, 35, 50],
#                          'min_samples_split': [4, 6, 10, 14, 18, 22]},
#              scoring='neg_mean_squared_error')

# %%
tree_model = DecisionTreeRegressor(max_depth=5,max_leaf_nodes=35,min_samples_split=4)
tree_model.fit(X_train,y_train)
y_pred = tree_model.predict(X_test)
metrics(y_test,y_pred)
# Out:
# MAE: 1634.7025771205917, percentege: 14.282205154221046
#  RSME: 2421.3459923728983, percentage: 21.15501663509616

# %%
sns.regplot(x=y_test,y=y_pred)
plt.show()

# %% [markdown]
# # Optimal Random Forest Machine Learning:

# %%
from sklearn.ensemble import RandomForestRegressor
max_depth = [8,10,12]
n_estimators = [10,20,30,40]
max_features = [20,25,30]
max_leaf_nodes = [40,35]
min_samples_split = [5]
min_impurity_decrease = [0.03,0.04,0.05,0.07]
ccp_alpha = [0.2,0.15,0.1,0.01,0]
params = {'n_estimators':n_estimators,
          'max_depth': max_depth,
          'max_features':max_features,
          'min_samples_split':min_samples_split,
          'max_leaf_nodes':max_leaf_nodes,
          'min_impurity_decrease':min_impurity_decrease,
          'ccp_alpha':ccp_alpha}
forset_model = RandomForestRegressor()
gridCV = GridSearchCV(forset_model,params,scoring='neg_mean_squared_error',n_jobs=-1)
gridCV.fit(X_train,y_train)
gridCV.best_estimator_

# %%
optimal_forest_model = RandomForestRegressor(n_estimators=10,max_features=13,max_depth=12,max_leaf_nodes=35,
                                             min_samples_split=5,ccp_alpha=0.15,min_impurity_decrease=0.07,random_state=42)
optimal_forest_model.fit(X_train,y_train)
y_pred = optimal_forest_model.predict(X_test)
metrics(y_test,y_pred)
sns.regplot(x=y_test,y=y_pred)
plt.xlabel('Test')
plt.ylabel('Predictions')
plt.title('Test vs Predictions')
plt.show()

# %%
plt.figure(figsize=(150,120), dpi=50)
plot_tree(optimal_forest_model, feature_names=X.columns.tolist(), filled=True)
plt.show()

# %% [markdown]
# # Model Deployment:

# %%
from joblib import dump,load
final_forest_model = RandomForestRegressor(n_estimators=120,max_features=9,bootstrap=False,min_samples_split=4)
final_forest_model.fit(X,y)
dump(final_forest_model,'final_forest_model.joblib')
loaded_model = load('final_forest_model.joblib')
new_data = pd.DataFrame({
'symboling': [1, 2],
'normalized-losses': [95, 84],
'make': ['toyota', 'honda'],
'fuel-type': ['gas', 'gas'],
'aspiration': ['std', 'std'],
'num-of-doors': ['four', 'four'],
'body-style': ['sedan', 'hatchback'],
'drive-wheels': ['fwd', 'fwd'],
'engine-location': ['front', 'front'],
'wheel-base': [98.0, 96.5],
'length': [176.2, 167.0],
'width': [66.5, 65.4],
'height': [54.3, 52.6],
'curb-weight': [2579, 2204],
'engine-type': ['ohc', 'ohc'],
'num-of-cylinders': ['four', 'four'],
'engine-size': [108, 97],
'fuel-system': ['mpfi', '2bbl'],
'bore': [3.50, 3.19],
'stroke': [2.80, 3.03],
'compression-ratio': [8.8, 9.6],
'horsepower': [75, 76],
'peak-rpm': [5000, 6000],
'city-mpg': [30, 30],
'highway-mpg': [38, 34]
})
new_data = pd.get_dummies(new_data,columns=['make','fuel-type','aspiration','num-of-doors','body-style','drive-wheels','engine-location','engine-type','num-of-cylinders','fuel-system'])
pred = loaded_model.predict(new_data)
pred

# %% [markdown]
# # unable to predict the new data beacuse some of the values are missing and don't create column in the dummies process, therefore the features do not match
